# %% [markdown]
# <a href="https://colab.research.google.com/github/mobillionairesburner/mobillionairesburner/blob/main/Lab_Notebook_Fall_2023_Randelson_MSMCTBT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab 1 : **Week 1 Goal** : To set up a notebook
#
# > Indented block

# %%
#We are going to begin by defining variables
a = 2
b = 4
c = 7

# %%
#Create a new variable from the defined list of variables
x = a + c
#Print () used to denote what you would like to see in the output
print(x)
# Out:
# 9

# %% [markdown]
# Congratualations - you have set up a notebook and ran your first line of code
# Mathematical symbols multiply * add + subtract - divide /

# %% [markdown]
# 🎓🍃💡

# %% [markdown]
# Week 2 Lab - Taking a look at Functions
#
# We are going to create a data frame using a list

# %%
#list1 = ['I','Love','MSM','Program']
#Pandas and Numpy are two important libraries within Python - have written functions and allow the programmer to create additional functions without writing it from scratch

import pandas as pd
import numpy as np

list1 = ['I','love','MSBT MCT','Program']
df = pd.DataFrame(data=list1)
df
# Out:
#           0
# 0         I
# 1      love
# 2  MSBT MCT
# 3   Program
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby(0).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
list2 = [4,5,9,-3,0,1]
max(list2)
# Out:
# 9

# %%
from numpy.core.fromnumeric import sort
sort(list2)
# Out:
# array([-3,  0,  1,  4,  5,  9])

# %%
list2 = [4,5,9,-3,0,1]
list2.remove(4)
print(list2)
# Out:
# [5, 9, -3, 0, 1]

# %% [markdown]
# **Lab Assignment Question 1** = Make a numeric list, sort by increasing value, report 2 values, print new list

# %%
#adding elements in a given list
list3 = ['R','SAS','Excel']#basic programs
list3.insert(2,'python')
list3.insert(4,'prism')
list3
# Out:
# ['R', 'SAS', 'python', 'Excel', 'prism']

# %%
df = pd.DataFrame(data=list3)
df
# Out:
#         0
# 0       R
# 1     SAS
# 2  python
# 3   Excel
# 4   prism

# %% [markdown]
# Define function with an argument

# %%
def even_odd(num):
  if(num%2==0):
    return'even_number'
  else:
      return'odd_number'

# %%
even_odd(36)
# Out:
# 'even_number'

# %%
even_odd(15)
# Out:
# 'odd_number'

# %%
#example of mis spacing

def even_odd(num):
  if(num%2==0):
    return'even_number'
  else:
      return'odd_number'

# %% [markdown]
# Define a function using a list

# %%
def unique(my_list):
  l=[]
  for i in my_list:
    if(i not in l):
      l.append(i)
  return l

# %%
list = [1,2,2,2,3,4,4,4,14,87,87]
unique(list)
# Out:
# [1, 2, 3, 4, 14, 87]

# %% [markdown]
# Concludes lab 2 generating list and writing basic functions

# %% [markdown]
# LAB 3 - DATA ANALYSIS

# %%
# Library to suppress warnings or deprecation notes
import warnings
warnings.filterwarnings('ignore')

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read in the data
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %% [markdown]
# # New Section

# %%
#Look at the basic Statistics
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
#data distribution
sns.distplot(df['population'])
plt.show()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
sns.displot(df['median_income'])
plt.show()

# %%
#Looking at coorelations - relationships within data
corr_matrix = df.corr()
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# population           0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070869    0.111572    0.051062      -0.018701
# latitude                 -0.068245   -0.117318   -0.068296      -0.072363
# ...

# %%
#Look at the relationships of the variables using a heatmap
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
#create a new variable to look at the ones with positive coorelations
num_columns=['total_bedrooms','total_rooms','population']

# %%
from pydoc import describe
df[num_columns].describe().T
# Out:
#                  count         mean          std  min     25%     50%  \
# total_bedrooms  3000.0   529.950667   415.654368  2.0   291.0   437.0
# total_rooms     3000.0  2599.578667  2155.593332  6.0  1401.0  2106.0
# population      3000.0  1402.798667  1030.543012  5.0   780.0  1155.0
#
#                     75%      max
# total_bedrooms   636.00   5419.0
# total_rooms     3129.00  30450.0
# population      1742.75  11935.0

# %%
#look at your data visually
df[num_columns].hist(figsize=(14,14))
plt.show()

# %%
#look at the correlation between the variables you  are interested in
plt.figure(figsize = (15,8))
sns.heatmap(df[num_columns].corr(), annot=True, fmt='0.2f', cmap= 'YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# LAB 3 - ASSIGNMENT

# %%
# Library to suppress warnings or deprecation notes
import warnings
warnings.filterwarnings('ignore')

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read in the data
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#data distribution
sns.distplot(df['households'])
plt.show()

# %%
sns.displot(df['total_rooms'])
plt.show()

# %%
sns.displot(df['population'])
plt.show()

# %%
#Looking at coorelations - relationships within data
corr_matrix = df.corr()
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %%
#Look at the relationships of the variables using a heatmap
sns.heatmap(corr_matrix,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-26317a6b77a5> in <cell line: 2>()
#       1 #Look at the relationships of the variables using a heatmap
# ----> 2 sns.heatmap(corr_matrix,annot=True)
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# **Final Project - MSBT MCT **
# Linear Regression Model

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-eed165fa-0503-4319-8468-5e46483a1ec6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eed165fa-0503-4319-8468-5e46483a1ec6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded['Cannabis_Retail_Sales_by_Week_Ending.csv']))
dataset.head(10)
# Out:
#   Week Ending  Adult-Use Retail Sales  Medical Marijuana Retail Sales  \
# 0  01/14/2023              1485019.32                      1776700.69
# 1  01/21/2023              1487815.81                      2702525.61
# 2  01/28/2023              1553216.30                      2726237.56
# 3  01/31/2023               578840.62                       863287.86
# 4  02/04/2023              1047436.20                      1971731.40
# 5  02/11/2023              1671205.80                      2815023.87
# 6  02/18/2023              1742486.74                      3008219.03
# 7  02/25/2023              1862822.43                      2793882.27
# 8  02/28/2023               700300.78                       853033.11
# 9  03/04/2023              1355673.59                      2145964.90
#
#    Total Adult-Use and Medical Sales  Adult-Use Products Sold  \
# 0                         3261720.01                  33610.0
# 1                         4190341.42                  33005.0
# ...

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-19f7ef69ea28> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...

# %%
X = X.apply(pd.to_numeric, errors='coerce')
Y = Y.apply(pd.to_numeric, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-4c693906c988> in <cell line: 1>()
# ----> 1 X = X.apply(pd.to_numeric, errors='coerce')
#       2 Y = Y.apply(pd.to_numeric, errors='coerce')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'apply'
